# %%
import pandas as pd
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori,association_rules
import seaborn as sns

# %%
path= "H:\\study\\Association Rules\\Assignments\\book.csv"

# %%
df = pd.read_csv(path)

# %%
df_ap = apriori(df,min_support=0.072,max_len=4,use_colnames = True)

# %%
df_ap
# Out:
#     support                                itemsets
# 0    0.4230                              (ChildBks)
# 1    0.2475                              (YouthBks)
# 2    0.4310                               (CookBks)
# 3    0.2820                              (DoItYBks)
# 4    0.2145                                (RefBks)
# ..      ...                                     ...
# 60   0.0745   (DoItYBks, ChildBks, CookBks, RefBks)
# 61   0.0820   (DoItYBks, ChildBks, CookBks, ArtBks)
# 62   0.0890  (DoItYBks, ChildBks, CookBks, GeogBks)
# 63   0.0785    (GeogBks, ChildBks, CookBks, RefBks)
# 64   0.0835    (GeogBks, ChildBks, CookBks, ArtBks)
#
# [65 rows x 2 columns]

# %%
df_ar = association_rules(df_ap,metric='lift',min_threshold=1)

# %%
df_ar[df_ar['confidence']> 0.7]
# Out:
#                         antecedents          consequents  antecedent support  \
# 7                          (RefBks)           (ChildBks)              0.2145
# 11                        (GeogBks)           (ChildBks)              0.2760
# 13                       (ItalCook)           (ChildBks)              0.1135
# 27                         (RefBks)            (CookBks)              0.2145
# 33                       (ItalCook)            (CookBks)              0.1135
# 46             (YouthBks, ChildBks)            (CookBks)              0.1650
# 47              (YouthBks, CookBks)           (ChildBks)              0.1620
# 52             (DoItYBks, YouthBks)           (ChildBks)              0.1155
# 59               (YouthBks, RefBks)           (ChildBks)              0.0965
# 65               (YouthBks, ArtBks)           (ChildBks)              0.1010
# 71              (YouthBks, GeogBks)           (ChildBks)              0.1205
# ...

# %% [markdown]
# Cross-Selling can be improved by combining products - items
# - The book shop layout can be changed so that sales can be improved when certain items are kept together.
# - Promotional activities which are an advertising campaign can be carried out to increase the sales of books that customers do not buy.
# - Collective discounts can be offered on these books if the customer buys both of them.

# %%
plt.figure(figsize=(15,15))
df_ar[df_ar['confidence']> 0.7].plot()
# Out:
# <AxesSubplot:>

# %%
df_ar[df_ar['confidence']> 0.7].plot(kind  ='scatter',x='confidence',y='support')
# Out:
# <AxesSubplot:xlabel='confidence', ylabel='support'>

# %%
df_ar[df_ar['confidence']> 0.7].plot(kind  ='scatter',y='lift',x='antecedent support')
# Out:
# <AxesSubplot:xlabel='antecedent support', ylabel='lift'>

# %%
df_ar[df_ar['confidence']> 0.7].plot(kind = 'scatter',x='consequent support',y='lift')
# Out:
# <AxesSubplot:xlabel='consequent support', ylabel='lift'>

# %%
df_ar.plot(kind='scatter',x='confidence',y='conviction')
# Out:
# <AxesSubplot:xlabel='confidence', ylabel='conviction'>
